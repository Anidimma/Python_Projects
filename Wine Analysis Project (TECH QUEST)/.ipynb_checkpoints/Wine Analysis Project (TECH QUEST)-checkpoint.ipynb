# %% [markdown]
# 1.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display# come back to this
# %matplotlib inline

# %%
data = pd.read_csv(r'../input/02_WineDataset.csv')
pd.options.display.max_columns = None
pd.options.display.max_rows = None
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
data.isnull().any().any()
# Out:
# False

# %%
data.corr()['quality']
# Out:
# fixed acidity          -0.076743
# volatile acidity       -0.265699
# citric acid             0.085532
# residual sugar         -0.036980
# chlorides              -0.200666
# free sulfur dioxide     0.055463
# total sulfur dioxide   -0.041385
# density                -0.305858
# pH                      0.019506
# sulphates               0.038485
# alcohol                 0.444319
# quality                 1.000000
# Name: quality, dtype: float64

# %%
data.rename(columns={'fixed acidity': 'fixed_acidity',
                     'citric acid':'citric_acid',
                     'volatile acidity':'volatile_acidity',
                     'residual sugar':'residual_sugar',
                     'free sulfur dioxide':'free_sulfur_dioxide',
                     'total sulfur dioxide':'total_sulfur_dioxide'},
            inplace=True)

# %%
data.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3, 9])

# %%
data['free_sulfur_dioxide'].unique()
# Out:
# array([ 11. ,  25. ,  15. ,  17. ,  13. ,   9. ,  16. ,  52. ,  51. ,
#         35. ,   6. ,  29. ,  23. ,  10. ,  21. ,   4. ,  14. ,   8. ,
#         22. ,  40. ,   5. ,   3. ,   7. ,  12. ,  30. ,  33. ,  50. ,
#         19. ,  20. ,  27. ,  18. ,  28. ,  34. ,  42. ,  41. ,  37. ,
#         32. ,  36. ,  24. ,  26. ,  39. ,  40.5,  68. ,  31. ,  38. ,
#         43. ,  47. ,   1. ,  54. ,  46. ,  45. ,   2. ,   5.5,  53. ,
#         37.5,  57. ,  48. ,  72. ,  55. ,  66. ,  56. ,  63. ,  62. ,
#         44. ,  81. ,  50.5,  69. ,  65. ,  64. ,  60. ,  59. ,  49. ,
#         58. ,  61. ,  75. ,  76. ,  64.5,  82. , 131. ,  38.5,  82.5,
#         87. ,  73.5,  83. ,  67. ,  79. ,  70. ,  77. , 122.5,  78. ,
#         11.5,  80. ,  44.5,  35.5,  73. ,  71. ,  15.5,  88. ,  77.5,
#         41.5, 118.5,  96. ,  52.5, 146.5,  48.5, 128. , 110. ,  42.5,
#         39.5,  19.5,  85. ,  74. ,  89. ,  86. ,  93. ,  30.5, 138.5,
# ...

# %%
data.free_sulfur_dioxide.value_counts()
# Out:
# 29.0     183
# 6.0      170
# 26.0     161
# 15.0     157
# 31.0     152
# 24.0     152
# 17.0     149
# 34.0     146
# 35.0     144
# 23.0     142
# 36.0     138
# 28.0     135
# 25.0     135
# 10.0     134
# 21.0     134
# 20.0     131
# 32.0     131
# 5.0      129
# 27.0     128
# 18.0     126
# 12.0     126
# 22.0     124
# 19.0     123
# 33.0     123
# 16.0     119
# 14.0     118
# 30.0     115
# 37.0     114
# 13.0     112
# 41.0     111
# 38.0     111
# 40.0     109
# 11.0     104
# 45.0     104
# 7.0       96
# 39.0      94
# 47.0      92
# 9.0       91
# 8.0       91
# 42.0      89
# 49.0      82
# 52.0      75
# 44.0      75
# 48.0      70
# 53.0      69
# 43.0      66
# 50.0      66
# 46.0      65
# 54.0      62
# 55.0      60
# 3.0       59
# 51.0      58
# 4.0       52
# 61.0      47
# 57.0      45
# 56.0      42
# 59.0      39
# 60.0      38
# 58.0      37
# 63.0      30
# 62.0      29
# 68.0      26
# 64.0      23
# 67.0      22
# 66.0      18
# 69.0      17
# ...

# %%
data['free_sulfur_dioxide'].describe()
# Out:
# count    6497.000000
# mean       30.525319
# std        17.749400
# min         1.000000
# 25%        17.000000
# 50%        29.000000
# 75%        41.000000
# max       289.000000
# Name: free_sulfur_dioxide, dtype: float64

# %%
data.quality.value_counts().sort_index()
# Out:
# 3      30
# 4     216
# 5    2138
# 6    2836
# 7    1079
# 8     193
# 9       5
# Name: quality, dtype: int64

# %%
import numpy as np
import seaborn as sns

# %%
ax = sns.catplot(x='quality', data=data,kind='count');
ax.fig.suptitle('Distribution of the Quality');

# %%
pd.plotting.scatter_matrix(data,alpha=0.3,figsize=(40,40),diagonal='kde');

# %%
correlate=data.corr()
plt.figure(figsize=(14,8))
ax = sns.heatmap(correlate, annot = True, 
            linewidth=0,vmin=-1,cmap='RdBu_r')#notation: "annot" not "annote"
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5);

# %%
correlate['quality'].sort_values()
# Out:
# density                -0.305858
# volatile_acidity       -0.265699
# chlorides              -0.200666
# fixed_acidity          -0.076743
# total_sulfur_dioxide   -0.041385
# residual_sugar         -0.036980
# pH                      0.019506
# sulphates               0.038485
# free_sulfur_dioxide     0.055463
# citric_acid             0.085532
# alcohol                 0.444319
# quality                 1.000000
# Name: quality, dtype: float64

# %%
data['alcohol'].describe()
# Out:
# count    6497.000000
# mean       10.491801
# std         1.192712
# min         8.000000
# 25%         9.500000
# 50%        10.300000
# 75%        11.300000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
plt.figure(figsize=(10,15))

for pl,col in enumerate(list(data.columns.values)):
    plt.subplot(4,3,pl+1)
    sns.set()
    sns.boxplot(col,data=data)
    plt.tight_layout()

# %%
data.iloc[:,:11].head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
plt.figure(figsize=(10,15))

for pl,col in enumerate(list(data.iloc[:,:11].columns.values)):
    plt.subplot(4,3,pl+1)
    ax = sns.violinplot(y= data[col],x='quality',data=data, scale='count')
    
    plt.tight_layout()

# %%
for pl,col in enumerate(list(data.iloc[:,:11].columns.values)):
 
    sns.set()
    sns.boxplot(x='quality',y=col,data=data)
   
    plt.title('');
    plt.ylabel(col);
    plt.show();
    plt.tight_layout();
    plt.close() 
    
    sns.set()
    sns.boxplot(x='quality',y=col,data=data,showfliers=False) 
    '''Testing'''
    plt.title('');
    plt.ylabel(col);
    plt.show();
    plt.tight_layout();
    plt.close() 
    
    sns.set()
    sns.violinplot(y= col ,x='quality',data=data, scale='count')
    plt.title('');
    plt.ylabel(col);
    plt.show();
    plt.tight_layout();
    plt.close() 
    
    sns.set
    sns.lmplot(x='quality',y=col,data=data,fit_reg=True)
    plt.title('');
    plt.ylabel(col);
    plt.show();
    plt.tight_layout();
    plt.close() 
    
    
    if col == 'chlorides':
        print('Yes')
# Out:
# Yes

# %%
for pl,col in enumerate(list(data.iloc[:,:11].columns.values)):
 
    
    sns.set()
    sns.violinplot(y= col ,x='rating',data=data, scale='count')
    plt.title('');
    plt.ylabel(col);
    plt.show();
    plt.tight_layout();
    plt.close() 
    
    sns.set()
    sns.swarmplot(x='rating',y=col,data=data)
    plt.title('');
    plt.ylabel(col);
    plt.show();
    plt.tight_layout();
    plt.close()

# %%
condition = [(data['quality']>6),(data['quality']<=4)]

rating = ['good','bad']

# %%
data['rating'] = np.select(condition,rating,default='average')
data.rating.value_counts()
# Out:
# average    4974
# good       1277
# bad         246
# Name: rating, dtype: int64

# %%
data.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality   rating
# 0      9.4        5  average
# ...

# %%
data[[('rating'),('quality')]].head(25)
# Out:
#      rating  quality
# 0   average        5
# 1   average        5
# 2   average        5
# 3   average        6
# 4   average        5
# 5   average        5
# 6   average        5
# 7      good        7
# 8      good        7
# 9   average        5
# 10  average        5
# 11  average        5
# 12  average        5
# 13  average        5
# 14  average        5
# 15  average        5
# 16     good        7
# 17  average        5
# 18      bad        4
# 19  average        6
# 20  average        6
# 21  average        5
# 22  average        5
# 23  average        5
# 24  average        6

# %%
data.groupby('rating')['quality'].value_counts()
# Out:
# rating   quality
# average  6          2836
#          5          2138
# bad      4           216
#          3            30
# good     7          1079
#          8           193
#          9             5
# Name: quality, dtype: int64

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
data.head(1)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4               0.7          0.0             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality   rating
# 0      9.4        5  average

# %%
X.head()
# Out:
#    alcohol  density  sulphates    pH  free_sulfur_dioxide  citric_acid
# 0      9.4   0.9978       0.56  3.51                 11.0         0.00
# 1      9.8   0.9968       0.68  3.20                 25.0         0.00
# 2      9.8   0.9970       0.65  3.26                 15.0         0.04
# 3      9.8   0.9980       0.58  3.16                 17.0         0.56
# 4      9.4   0.9978       0.56  3.51                 11.0         0.00

# %%
bins = (2, 4, 9)
group_names = ['bad', 'good']
data['quality'] = pd.cut(data['quality'], bins = bins, labels = group_names)

# %%
data.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality   rating
# 0      9.4    good  average
# 1      9.8    good  average
# ...

# %%
dfL = np.array(data['quality'])

dfL = pd.DataFrame(dfL)

data['quality'] = dfL.apply(lambda x: x.map({'good':1,'bad':0}))

# %%
dfL.head()
# Out:
#       0
# 0  good
# 1  good
# 2  good
# 3  good
# 4  good

# %%
data.head(30)
# Out:
#     fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %%
X =  data[['alcohol','density','sulphates','pH','free_sulfur_dioxide','citric_acid']]
y =  data['quality']

# %%
from sklearn.model_selection import train_test_split, cross_val_score
X_tr,X_t,y_tr,y_t = train_test_split(X,y)

# %%
X_tr.shape, X_t.shape
# Out:
# ((4872, 6), (1625, 6))

# %%
from sklearn.preprocessing import StandardScaler

# %%
stds= StandardScaler()



X_tr= stds.fit_transform(X_tr)
X_t = stds.fit_transform(X_t)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
logr = LogisticRegression(max_iter=1000);

logr.fit(X_tr,y_tr);

# %%
ytr_pred = logr.predict(X_tr)
yt_pred = logr.predict(X_t)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score;
def generateClassificationReport(y_true,y_pred):
    print(classification_report(y_true,y_pred));
    print(confusion_matrix(y_true,y_pred));
    print('\n\nTrain Accuracy is: ',
          round(100*accuracy_score(y_true,y_pred),3),'%\n');

# %%
generateClassificationReport(y_tr,ytr_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       175
#            1       0.96      1.00      0.98      4697
#
#     accuracy                           0.96      4872
#    macro avg       0.48      0.50      0.49      4872
# weighted avg       0.93      0.96      0.95      4872
#
# [[   0  175]
#  [   0 4697]]
#
#
# Train Accuracy is:  96.408 %
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
generateClassificationReport(y_t,yt_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        71
#            1       0.96      1.00      0.98      1554
#
#     accuracy                           0.96      1625
#    macro avg       0.48      0.50      0.49      1625
# weighted avg       0.91      0.96      0.93      1625
#
# [[   0   71]
#  [   0 1554]]
#
#
# Train Accuracy is:  95.631 %

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=100)

rfc.fit(X_tr,y_tr)
# Out:
# RandomForestClassifier()

# %%
ytr_pred = rfc.predict(X_tr)

generateClassificationReport(y_tr,ytr_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       175
#            1       1.00      1.00      1.00      4697
#
#     accuracy                           1.00      4872
#    macro avg       1.00      1.00      1.00      4872
# weighted avg       1.00      1.00      1.00      4872
#
# [[ 175    0]
#  [   0 4697]]
#
#
# Train Accuracy is:  100.0 %

# %%
yt_pred = rfc.predict(X_t);

generateClassificationReport(y_t,yt_pred);
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.06      0.11        71
#            1       0.96      1.00      0.98      1554
#
#     accuracy                           0.96      1625
#    macro avg       0.88      0.53      0.54      1625
# weighted avg       0.95      0.96      0.94      1625
#
# [[   4   67]
#  [   1 1553]]
#
#
# Train Accuracy is:  95.815 %

# %%
#NAIVE BAYES
from sklearn.naive_bayes import GaussianNB

classifier = GaussianNB()
classifier.fit(X_tr,y_tr)

ytr_pred = classifier.predict(X_tr)

generateClassificationReport(y_tr,ytr_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.25      0.03      0.06       175
#            1       0.97      1.00      0.98      4697
#
#     accuracy                           0.96      4872
#    macro avg       0.61      0.52      0.52      4872
# weighted avg       0.94      0.96      0.95      4872
#
# [[   6  169]
#  [  18 4679]]
#
#
# Train Accuracy is:  96.162 %

# %%
yt_pred = classifier.predict(X_t)

generateClassificationReport(y_t,yt_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.33      0.01      0.03        71
#            1       0.96      1.00      0.98      1554
#
#     accuracy                           0.96      1625
#    macro avg       0.65      0.51      0.50      1625
# weighted avg       0.93      0.96      0.94      1625
#
# [[   1   70]
#  [   2 1552]]
#
#
# Train Accuracy is:  95.569 %

# %%
from sklearn.svm import SVC

# %%
classifier = SVC()
classifier.fit(X_tr,y_tr)
ytr_pred = classifier.predict(X_tr)
generateClassificationReport(y_tr,ytr_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.02      0.04       175
#            1       0.96      1.00      0.98      4697
#
#     accuracy                           0.96      4872
#    macro avg       0.98      0.51      0.51      4872
# weighted avg       0.97      0.96      0.95      4872
#
# [[   4  171]
#  [   0 4697]]
#
#
# Train Accuracy is:  96.49 %

# %%
yt_pred = classifier.predict(X_t)
generateClassificationReport(y_t,yt_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        71
#            1       0.96      1.00      0.98      1554
#
#     accuracy                           0.96      1625
#    macro avg       0.48      0.50      0.49      1625
# weighted avg       0.91      0.96      0.93      1625
#
# [[   0   71]
#  [   0 1554]]
#
#
# Train Accuracy is:  95.631 %
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier = DecisionTreeClassifier()
classifier.fit(X_tr,y_tr)
ytr_pred = classifier.predict(X_tr)

generateClassificationReport(y_tr,ytr_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       175
#            1       1.00      1.00      1.00      4697
#
#     accuracy                           1.00      4872
#    macro avg       1.00      1.00      1.00      4872
# weighted avg       1.00      1.00      1.00      4872
#
# [[ 175    0]
#  [   0 4697]]
#
#
# Train Accuracy is:  100.0 %

# %%
yt_pred = classifier.predict(X_t)

generateClassificationReport(y_t,yt_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.21      0.25      0.23        71
#            1       0.97      0.96      0.96      1554
#
#     accuracy                           0.93      1625
#    macro avg       0.59      0.60      0.60      1625
# weighted avg       0.93      0.93      0.93      1625
#
# [[  18   53]
#  [  68 1486]]
#
#
# Train Accuracy is:  92.554 %

# %%
from sklearn.linear_model import SGDClassifier

from sklearn.model_selection import GridSearchCV

# %%
sgd = SGDClassifier(penalty=None)
sgd.fit(X_tr, y_tr)
ytr_pred = sgd.predict(X_tr)
generateClassificationReport(y_tr,ytr_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       175
#            1       0.96      1.00      0.98      4697
#
#     accuracy                           0.96      4872
#    macro avg       0.48      0.50      0.49      4872
# weighted avg       0.93      0.96      0.95      4872
#
# [[   0  175]
#  [   0 4697]]
#
#
# Train Accuracy is:  96.408 %
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
yt_pred = sgd.predict(X_t)
generateClassificationReport(y_t,yt_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        71
#            1       0.96      1.00      0.98      1554
#
#     accuracy                           0.96      1625
#    macro avg       0.48      0.50      0.49      1625
# weighted avg       0.91      0.96      0.93      1625
#
# [[   0   71]
#  [   0 1554]]
#
#
# Train Accuracy is:  95.631 %
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
